# %% [markdown]
# # Codveda Technologies Internship
#
# # Level 1 - Task 1: Data Cleaning and Preprocessing
#
# ### Intern Name:
# **Ashvini Manohar Jadhav**
#
# ### Domain:
# **Data Analysis**
#
# ### Tools Used:
# - Python
# - Pandas
# - NumPy
# - Jupyter Notebook
#
# ### Dataset:
# House Prediction Dataset (Boston Housing Dataset)

# %% [markdown]
# ## Project Objective
#
# The objective of this task is to clean and preprocess the House Prediction dataset before performing data analysis.
#
# The preprocessing steps include:
#
# - Loading the dataset
#
# - Understanding dataset structure
#
#
# - Checking data types
#
#
# - Identifying missing values
#
#
# - Detecting duplicate records
#
#
# - Verifying data consistency
#
#
# - Saving the cleaned dataset

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Step 1: Load the Dataset

# %%
column_names = [
    'CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE',
    'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV'
]

df = pd.read_csv("house_prediction.csv" ,sep=r"\s+", header=None ,names=column_names)

df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# ## Step 2: Dataset Overview

# %%
# Display the shape of the dataset
print("Shape of Dataset:", df.shape)
# Out:
# Shape of Dataset: (506, 14)

# %%
# Display column names
print(df.columns)
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='str')

# %%
# Display dataset information
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %% [markdown]
# ### Observation
#
# - The dataset contains **506 rows** and **14 columns**.
#
# - All columns were loaded successfully.
#
#
# - Data types are numerical.

# %% [markdown]
# ## Step 3: Summary Statistics

# %%
# Statistical summary
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# ## Step 4: Check Missing Values

# %%
# Check missing values
missing_values = df.isnull().sum()

print(missing_values)
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %% [markdown]
# ### Observation
#
# No missing values were found in the dataset.
#
# Therefore, no imputation or deletion of records was required.

# %% [markdown]
# ## Step 5: Check Duplicate Records

# %%
duplicates = df.duplicated().sum()

print("Duplicate Rows:", duplicates)
# Out:
# Duplicate Rows: 0

# %% [markdown]
# ### Observation
#
# No duplicate records were found in the dataset.
#
# Therefore, no duplicate rows were removed.

# %% [markdown]
# ## Step 6: Verify Data Types

# %%
# Display data types
df.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS         int64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX        float64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %%
# Check unique values in CHAS
print("Unique values in CHAS:", df["CHAS"].unique())

# Check data types again
print(df.dtypes)
# Out:
# Unique values in CHAS: [0 1]
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS         int64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX        float64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %% [markdown]
# ### Observation
#
# All columns have appropriate numerical data types.
#
# No data type conversion was required.

# %% [markdown]
# ## Step 7: Save the Cleaned Dataset

# %%
# Save cleaned dataset
df.to_csv("cleaned_house_prediction.csv", index=False)

print("Cleaned dataset saved successfully!")
# Out:
# Cleaned dataset saved successfully!

# %% [markdown]
# # Conclusion
#
# The House Prediction dataset was successfully loaded and inspected.
#
# ### Completed preprocessing tasks:
#
# - Loaded the dataset using Pandas.
#
# - Verified the dataset structure.
#
# - Checked data types.
#
# - Checked for missing values.
#
# - Checked for duplicate records.
#
# - Verified data consistency.
#
# - Saved the cleaned dataset.
#
# The dataset was already clean and ready for further analysis.
